# %%
import numpy as np

# %%
X=np.array([[1,0],[0,1]])
Y=np.array([[0,1],[1,0]])
Z=X+Y

# %%
Z
# Out:
# array([[1, 1],
#        [1, 1]])

# %%
X=np.array([[1,0,1],[2,2,2]]) 
out=X[0:2,2]
out
# Out:
# array([1, 2])

# %%
X=np.array([[1,0],[0,1]])
Y=np.array([[2,1],[1,2]]) 
Z=np.dot(X,Y)

# %%
Z
# Out:
# array([[2, 1],
#        [1, 2]])
